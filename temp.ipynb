# %%
# Resize image

from PIL import Image
import matplotlib.pyplot as plt

bg = Image.open("images/bg_0.jpg")
plt.imshow(bg)

width, height = bg.size

newsize = (int(width*0.5), int(height*0.5))
im1 = bg.resize(newsize)

plt.imshow(im1)

# %%
# Cropped image of above dimension
# (It will not change original image)
im2 = im1.crop((0, 0, 1274, 1274))

plt.imshow(im2)

im2.save("images/bg_0_cropped.jpg")

# %%
# Resize image

from PIL import Image
import matplotlib.pyplot as plt

im = Image.open("images/profile.jpg")
plt.imshow(im)

width, height = im.size
print(im.size)

plt.figure()
# Cropped image of above dimension
# (It will not change original image)
im2 = im.crop((325, 150, 1125, 950))

plt.imshow(im2)
print(im2.size)

im2.save("images/profile_cropped.jpg")
# Out:
# (1468, 1643)
# (800, 800)
